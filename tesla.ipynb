# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mamba
# Out:
# ...
#      |████████████████████████████████| 212 kB 34.4 MB/s eta 0:00:01
# ...
#   Created wheel for mamba: filename=mamba-0.11.2-py3-none-any.whl size=15391 sha256=55a7ec3c7901cf9d9fcaed348a7b7fa7dedf8c3834037b90338112d9f30742b0
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/c5/e3/1d/bf899e86efa8c92a7642eb3bef00c3d1c166789cac72d2dc5e
# ...
#   Created wheel for clint: filename=clint-0.5.1-py3-none-any.whl size=34474 sha256=7a030e1058365e686276b466228b6c91723c4ad7ddf6c951893ed65c907a2750
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/2c/69/16/04ffdd2e6fbbf2b3aa97970ba8d01c36d09df025f19f25c57e
# ...
#   Created wheel for args: filename=args-0.1.0-py3-none-any.whl size=3317 sha256=c1d5db5dd9ffeccff802f893f7ad8696103b1d29d7b3bd4f5d37bbcad2f53a32
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/35/22/2d/ee3fc491993d35adc89bcc8f558090cabefeff184a9537928d
# Successfully built mamba clint args
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mamba bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=3d4dc49f6963cb4baf12bf8c909d74070580adb6c738c0d2e41e3c02bc3ec5bb
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import imp
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
tesla = yf.Ticker('TSLA')

# %%
tesla_info = tesla.info
tesla_info
# Out:
# {'zip': '78725',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 99290,
# ...

# %%
url ="https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
data = requests.get(url).text
soup = BeautifulSoup(data,'html5lib')
tesla_revenue = pd.DataFrame(columns=['Date','Revenue'])
for row in soup.find('tbody').find_all('tr'):
    col = row.find_all('td')
    date = col[0].text
    revenue = col[1].text
    
    tesla_revenue = tesla_revenue.append({'Date':date,'Revenue':revenue},ignore_index=True)
    
tesla_revenue.head()
# Out:
#    Date  Revenue
# 0  2021  $53,823
# 1  2020  $31,536
# 2  2019  $24,578
# 3  2018  $21,461
# 4  2017  $11,759

# %%
tesla_revenue.tail(5)
# Out:
#     Date Revenue
# 8   2013  $2,013
# 9   2012    $413
# 10  2011    $204
# 11  2010    $117
# 12  2009    $112

# %%
tesla_share_price = tesla.history(period=)

# %%
tesla_revenue.reset_index(inplace=True)
tesla_revenue.plot(x='Date',y='Revenue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/wsuser/ipykernel_367/264687026.py in <module>
#       1 tesla_revenue.reset_index(inplace=True)
# ----> 2 tesla_revenue.plot(x='Date',y='Revenue')
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
GameStop = yf.Ticker('GME')

# %%
gamestop_data = GameStop.info
gamestop_data
# Out:
# {'zip': '76051',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 12000,
# ...

# %%
gamestop_stock_price = GameStop.history(period='max')
gamestop_stock_price.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2002-02-13  1.620129  1.693350  1.603296  1.691667  76216000        0.0
# 2002-02-14  1.712707  1.716074  1.670626  1.683250  11021600        0.0
# 2002-02-15  1.683250  1.687458  1.658002  1.674834   8389600        0.0
# 2002-02-19  1.666417  1.666417  1.578047  1.607504   7410400        0.0
# 2002-02-20  1.615920  1.662210  1.603296  1.662210   6892800        0.0
#
#             Stock Splits
# Date
# 2002-02-13           0.0
# 2002-02-14           0.0
# 2002-02-15           0.0
# 2002-02-19           0.0
# 2002-02-20           0.0

# %% [markdown]
# <h1><i><b>GameStop Stock Data Graph<h>

# %%
gamestop_stock_price.reset_index(inplace=True)
gamestop_stock_price.plot(x='Date',y='Open')
# Out:
# <AxesSubplot:xlabel='Date'>
